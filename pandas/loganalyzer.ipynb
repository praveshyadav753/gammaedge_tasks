# %%
import pandas as pd

# %%
df = pd.read_json("logs.json")
df
# Out:
#                           timestamp  level         service  \
# 0         2025-01-29 10:00:00+00:00   INFO        auth-api
# 1  2025-01-29 10:00:05.123000+00:00   WARN  data-processor
# 2  2025-01-29 11:00:11.245000+00:00   INFO      web-server
# 3  2025-01-29 10:00:15.367000+00:00  ERROR        database
# 4  2025-01-29 10:00:20.489000+00:00   INFO        auth-api
# 5  2025-01-29 10:00:25.612000+00:00  DEBUG  data-processor
# 6  2025-01-29 12:00:30.734000+00:00   INFO      web-server
# 7  2025-01-29 10:00:35.856000+00:00  ERROR    file-storage
# 8  2025-01-29 10:00:40.978000+00:00   INFO        auth-api
# 9  2025-01-29 10:00:46.100000+00:00   INFO      web-server
# 10 2025-01-29 10:00:51.223000+00:00   WARN  billing-engine
# 11 2025-01-29 01:00:56.345000+00:00   INFO  data-processor
# 12 2025-01-29 10:01:01.467000+00:00   INFO      web-server
# 13 2025-01-29 12:01:06.589000+00:00  ERROR        auth-api
# 14 2025-01-29 10:01:11.712000+00:00  DEBUG   cache-service
# ...

# %%
df.iloc[0]
# Out:
# timestamp             2025-01-29 10:00:00+00:00
# level                                      INFO
# service                                auth-api
# event                                user_login
# user_id                                   101.0
# status                                  success
# ip_address                          192.168.1.1
# record_id                                   NaN
# details                                     NaN
# method                                      NaN
# path                                        NaN
# status_code                                 NaN
# response_time_ms                            NaN
# error_code                                  NaN
# db_host                                     NaN
# message                                     NaN
# batch_id                                    NaN
# items_count                                 NaN
# disk_id                                     NaN
# available_space_gb                          NaN
# ...

# %%
df.loc[3]
# Out:
# timestamp              2025-01-29 10:00:15.367000+00:00
# level                                             ERROR
# service                                        database
# event                                connection_failure
# user_id                                             NaN
# status                                              NaN
# ip_address                                          NaN
# record_id                                           NaN
# details                                             NaN
# method                                              NaN
# path                                                NaN
# status_code                                         NaN
# response_time_ms                                    NaN
# error_code                                       5001.0
# db_host                                      db-prod-01
# message               Failed to connect to the database
# batch_id                                            NaN
# ...

# %%
df.iloc[1,3]
# Out:
# 'invalid_data_format'

# %%
df.head(3)
# Out:
#                          timestamp level         service                event  \
# 0        2025-01-29 10:00:00+00:00  INFO        auth-api           user_login
# 1 2025-01-29 10:00:05.123000+00:00  WARN  data-processor  invalid_data_format
# 2 2025-01-29 10:00:10.245000+00:00  INFO      web-server         http_request
#
#    user_id   status   ip_address  record_id  \
# 0    101.0  success  192.168.1.1        NaN
# 1      NaN      NaN          NaN     5543.0
# 2      NaN      NaN          NaN        NaN
#
#                                 details method  ... currency  reason  \
# 0                                   NaN    NaN  ...      NaN     NaN
# 1  missing required field 'client_name'    NaN  ...      NaN     NaN
# 2                                   NaN    GET  ...      NaN     NaN
#
#    processed_count  key source cpu_percent server_name  file_path  \
# 0              NaN  NaN    NaN         NaN         NaN        NaN
# ...

# %%
df.set_index("timestamp")
# Out:
#                                   level         service  \
# timestamp
# 2025-01-29 10:00:00+00:00          INFO        auth-api
# 2025-01-29 10:00:05.123000+00:00   WARN  data-processor
# 2025-01-29 10:00:10.245000+00:00   INFO      web-server
# 2025-01-29 10:00:15.367000+00:00  ERROR        database
# 2025-01-29 10:00:20.489000+00:00   INFO        auth-api
# 2025-01-29 10:00:25.612000+00:00  DEBUG  data-processor
# 2025-01-29 10:00:30.734000+00:00   INFO      web-server
# 2025-01-29 10:00:35.856000+00:00  ERROR    file-storage
# 2025-01-29 10:00:40.978000+00:00   INFO        auth-api
# 2025-01-29 10:00:46.100000+00:00   INFO      web-server
# 2025-01-29 10:00:51.223000+00:00   WARN  billing-engine
# 2025-01-29 10:00:56.345000+00:00   INFO  data-processor
# 2025-01-29 10:01:01.467000+00:00   INFO      web-server
# 2025-01-29 10:01:06.589000+00:00  ERROR        auth-api
# 2025-01-29 10:01:11.712000+00:00  DEBUG   cache-service
# ...

# %%
df
# Out:
#                           timestamp  level         service  \
# 0         2025-01-29 10:00:00+00:00   INFO        auth-api
# 1  2025-01-29 10:00:05.123000+00:00   WARN  data-processor
# 2  2025-01-29 10:00:10.245000+00:00   INFO      web-server
# 3  2025-01-29 10:00:15.367000+00:00  ERROR        database
# 4  2025-01-29 10:00:20.489000+00:00   INFO        auth-api
# 5  2025-01-29 10:00:25.612000+00:00  DEBUG  data-processor
# 6  2025-01-29 10:00:30.734000+00:00   INFO      web-server
# 7  2025-01-29 10:00:35.856000+00:00  ERROR    file-storage
# 8  2025-01-29 10:00:40.978000+00:00   INFO        auth-api
# 9  2025-01-29 10:00:46.100000+00:00   INFO      web-server
# 10 2025-01-29 10:00:51.223000+00:00   WARN  billing-engine
# 11 2025-01-29 10:00:56.345000+00:00   INFO  data-processor
# 12 2025-01-29 10:01:01.467000+00:00   INFO      web-server
# 13 2025-01-29 10:01:06.589000+00:00  ERROR        auth-api
# 14 2025-01-29 10:01:11.712000+00:00  DEBUG   cache-service
# ...

# %%
df.loc[(df.level=='INFO')]
# Out:
#                           timestamp level         service  \
# 0         2025-01-29 10:00:00+00:00  INFO        auth-api
# 2  2025-01-29 10:00:10.245000+00:00  INFO      web-server
# 4  2025-01-29 10:00:20.489000+00:00  INFO        auth-api
# 6  2025-01-29 10:00:30.734000+00:00  INFO      web-server
# 8  2025-01-29 10:00:40.978000+00:00  INFO        auth-api
# 9  2025-01-29 10:00:46.100000+00:00  INFO      web-server
# 11 2025-01-29 10:00:56.345000+00:00  INFO  data-processor
# 12 2025-01-29 10:01:01.467000+00:00  INFO      web-server
# 15 2025-01-29 10:01:16.834000+00:00  INFO      web-server
# 16 2025-01-29 10:01:21.956000+00:00  INFO  system-monitor
# 18 2025-01-29 10:01:32.200000+00:00  INFO        auth-api
# 19 2025-01-29 10:01:37.323000+00:00  INFO      web-server
# 21 2025-01-29 10:01:47.567000+00:00  INFO  data-processor
#
#                      event  user_id                status   ip_address  \
# 0               user_login    101.0               success  192.168.1.1
# ...

# %%
df.level.describe()
# Out:
# count       23
# unique       4
# top       INFO
# freq        13
# Name: level, dtype: object

# %%
df.level + ":" + df.service
# Out:
# 0            INFO:auth-api
# 1      WARN:data-processor
# 2          INFO:web-server
# 3           ERROR:database
# 4            INFO:auth-api
# 5     DEBUG:data-processor
# 6          INFO:web-server
# 7       ERROR:file-storage
# 8            INFO:auth-api
# 9          INFO:web-server
# 10     WARN:billing-engine
# 11     INFO:data-processor
# 12         INFO:web-server
# 13          ERROR:auth-api
# 14     DEBUG:cache-service
# 15         INFO:web-server
# 16     INFO:system-monitor
# 17    ERROR:data-processor
# 18           INFO:auth-api
# 19         INFO:web-server
# 20       WARN:file-storage
# 21     INFO:data-processor
# 22        DEBUG:web-server
# dtype: str

# %%
df.groupby('level')

# %%
df.groupby('level').service

# %%
df.groupby('level').count()
# Out:
#        timestamp  service  event  user_id  status  ip_address  record_id  \
# level
# DEBUG          3        3      3        1       0           0          0
# ERROR          4        4      4        1       0           0          0
# INFO          13       13     13        4       3           2          0
# WARN           3        3      3        2       0           0          1
#
#        details  method  path  ...  currency  reason  processed_count  key  \
# level                         ...
# DEBUG        0       0     0  ...         0       0                0    1
# ERROR        1       0     0  ...         0       0                0    0
# INFO         0       6     6  ...         0       0                1    0
# WARN         1       0     0  ...         1       1                0    0
#
#        source  cpu_percent  server_name  file_path  records_count  session_id
# level
# DEBUG       1            0            0          0              0           1
# ...

# %%
hourly=df.groupby(df.timestamp.dt.hour)
for hour, group_data in hourly:
    print(f"--- Hour: {hour:02d} ---")
    print(group_data.loc[0,5])
# Out:
# --- Hour: 01 ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/python/pandas/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:578, in pandas._libs.index.StringObjectEngine._check_type()
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 4
#       2 for hour, group_data in hourly:
#       3     print(f"--- Hour: {hour:02d} ---")
# ----> 4     print(group_data.loc[0,5])
#
# ...
